# %% [markdown]
# <a href="https://colab.research.google.com/github/bob8dod/ML-studying/blob/main/ML_DL/10_DL_Model_(train_test_split).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Using Package
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import pandas as pd
import numpy as np
import tensorflow as tf

# %%
#Set random seed
seed = 3
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
#Set Data
df = pd.read_csv('./dataset/sonar.csv', header=None)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
#Checking the Label _ Y_obj
df[[60]].describe()
# Out:
#          60
# count   208
# unique    2
# top       M
# freq    111

# %%
#Data Preprocessing
data = df.values
X = data[:,0:60].astype(float)
Y_obj = data[:,60]

#Transforming the Y (str->int)
e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)

#Split the Data(train, test)
x_train, x_test, y_train, y_test = train_test_split(X,Y, test_size=0.3, random_state=seed)

# %%
#Make Model
model = Sequential()
model.add(Dense(24,input_dim=60,activation='relu'))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
#Setting Model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(x_train, y_train, epochs=130, batch_size=5)
# model.save('my_model.h5') #Save the Model on Computer
# Out:
# Epoch 1/130
# 29/29 [==============================] - 1s 1ms/step - loss: 0.6935 - accuracy: 0.5119
# Epoch 2/130
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6557 - accuracy: 0.5705
# Epoch 3/130
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6415 - accuracy: 0.6272
# Epoch 4/130
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6203 - accuracy: 0.7032
# Epoch 5/130
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5981 - accuracy: 0.7444
# Epoch 6/130
# 29/29 [==============================] - 0s 1ms/step - loss: 0.6066 - accuracy: 0.7007
# Epoch 7/130
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5583 - accuracy: 0.7439
# Epoch 8/130
# 29/29 [==============================] - 0s 1ms/step - loss: 0.5584 - accuracy: 0.7030
# Epoch 9/130
# 29/29 [==============================] - 0s 2ms/step - loss: 0.5387 - accuracy: 0.7136
# Epoch 10/130
# ...

# %%
# del model                              #Delete Model in here for Test
# model = load_model('my_model.h5')      #Load Saved Model
print('Accuracy: %.4f' %(model.evaluate(x_test, y_test)[1])) #Evaluate the Model
# Out:
# WARNING:tensorflow:6 out of the last 13 calls to <function Model.make_test_function.<locals>.test_function at 0x0000010FFC9BBB80> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/guide/function#controlling_retracing and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# 2/2 [==============================] - 0s 2ms/step - loss: 0.6932 - accuracy: 0.7778
# Accuracy: 0.7778
