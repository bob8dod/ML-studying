# %% [markdown]
# <a href="https://colab.research.google.com/github/bob8dod/ML-studying/blob/main/ML_DL/11_DL_Model_(kflod_StratifiedKFold).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold

import tensorflow as tf
import numpy as np
import pandas as pd

# %%
seed = 3
np.random.seed(seed)
tf.random.set_seed(seed)

# %%
df = pd.read_csv('./dataset/sonar.csv', header=None)
df.head()
# Out:
#        0       1       2       3       4       5       6       7       8   \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#        9   ...      51      52      53      54      55      56      57  \
# 0  0.2111  ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872  ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194  ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264  ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459  ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#        58      59  60
# 0  0.0090  0.0032   R
# 1  0.0052  0.0044   R
# 2  0.0095  0.0078   R
# ...

# %%
df[[60]].describe()
# Out:
#          60
# count   208
# unique    2
# top       M
# freq    111

# %%
#Data Preprocessing
data = df.values
X = data[:,0:60].astype(float)
Y_obj = data[:,60]

#Data transforming
e = LabelEncoder()
e.fit(Y_obj)
Y = e.transform(Y_obj)

# %%
#KFold _ data split
n_fold = 10
skf=StratifiedKFold(n_splits=n_fold, shuffle=True, random_state=seed)

# %%
#Model Making,Setting,Operating
accuracy=[] #for saving all accuracy
for train,test in skf.split(X,Y): # 10 iterations
    model=Sequential()
    model.add(Dense(24,input_dim=60,activation='relu'))
    model.add(Dense(10,activation='relu'))
    model.add(Dense(1,activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    model.fit(X[train],Y[train],epochs=30, batch_size=10) #Fitting by train_set
    accuracy_k = "%.4f" %(model.evaluate(X[test], Y[test])[1]) #Evaluating by test_set
    accuracy.append(accuracy_k) #Saving as "string" not real number
# Out:
# Epoch 1/30
# 19/19 [==============================] - 1s 1ms/step - loss: 0.6916 - accuracy: 0.5319
# Epoch 2/30
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6696 - accuracy: 0.5449
# Epoch 3/30
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6565 - accuracy: 0.6339
# Epoch 4/30
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6423 - accuracy: 0.7195
# Epoch 5/30
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6353 - accuracy: 0.7054
# Epoch 6/30
# 19/19 [==============================] - 0s 1ms/step - loss: 0.6436 - accuracy: 0.6780
# Epoch 7/30
# 19/19 [==============================] - 0s 2ms/step - loss: 0.6110 - accuracy: 0.7529
# Epoch 8/30
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5932 - accuracy: 0.7420
# Epoch 9/30
# 19/19 [==============================] - 0s 2ms/step - loss: 0.5754 - accuracy: 0.7646
# Epoch 10/30
# ...

# %%
#Showing result
for i,value in enumerate(accuracy):
    print('[%02d]Flod:'%(i+1),value)
# Out:
# [01]Flod: 0.8095
# [02]Flod: 0.8571
# [03]Flod: 0.7619
# [04]Flod: 0.8571
# [05]Flod: 0.7619
# [06]Flod: 0.8095
# [07]Flod: 0.8095
# [08]Flod: 0.6667
# [09]Flod: 0.8000
# [10]Flod: 0.7000
